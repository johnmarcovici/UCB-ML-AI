# %% [markdown]
# ### Replicating Plots
#
# **Expected Time: 30 Minutes**
#
# **Total Points: 10**
#
# This activity focuses on duplicating a given plot using the appropriate plotting library.  The `gapminder` dataset from plotly is used.  For each Problem, you will be shown an image of a plot produced using `matplotlib`, `seaborn`, and `plotly`.  You are asked to replicate the plot and enter the appropriate code for each Problem.
#
# ## Index:
#
# - [Problem 1](#Problem-1)
# - [Problem 2](#Problem-2)
# - [Problem 3](#Problem-3)
# - [Problem 4](#Problem-4)
# - [Problem 5](#Problem-5)

# %%
import plotly.express as px
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#from notebook.services.config import ConfigManager; ConfigManager().update('notebook', {"CodeCell": {"cm_config": {"autoCloseBrackets": False}}})

# %%
gapminder = px.data.gapminder()

# %%
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
# Average GDP from the African continent only
display(gapminder.query('continent == "Africa"').gdpPercap.mean())
display(gapminder.query('continent == "Americas"').gdpPercap.std())
# Out:
# 2193.7545782857374
# 6396.764111749722

# %%
gapminder.continent.unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
#  6   iso_alpha  1704 non-null   object
#  7   iso_num    1704 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 106.6+ KB

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 1
#
# **Basic Histogram**
#
# **2 Points**
#
# ![](images/p1.png)

# %%
### GRADED
plt.hist(gapminder.lifeExp, density=False, color="darkblue", alpha=0.6, edgecolor="black", bins=15)
plt.title("Histogram of Life Expectancy")
# Out:
# Text(0.5, 1.0, 'Histogram of Life Expectancy')

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 2
#
# **A Kernel Density Estimate Plot**
#
# **2 Points**
#
# ![](images/p2.png)

# %%
### GRADED
import warnings; warnings.filterwarnings('ignore')
#sns.kdeplot(gapminder.lifeExp, fill=True, hue=gapminder.continent, multiple="stack")
sns.kdeplot(gapminder.lifeExp, fill=True, hue=gapminder.continent)
plt.xlabel("lifeExp")
plt.ylabel("Density")

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 3
#
# **Boxplots**
#
# **2 Points**
#
# ![](images/p3.png)

# %%
### GRADED
fig = px.box(gapminder, x="lifeExp", color="continent")
fig.show()
# Out:
# <div>                            <div id="86ecf52a-a327-4f32-bd06-b33bf93835fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86ecf52a-a327-4f32-bd06-b33bf93835fa")) {                    Plotly.newPlot(                        "86ecf52a-a327-4f32-bd06-b33bf93835fa",                        [{"alignmentgroup":"True","hovertemplate":"continent=Asia<br>lifeExp=%{x}<extra></extra>","legendgroup":"Asia","marker":{"color":"#636efa"},"name":"Asia","notched":false,"offsetgroup":"Asia","orientation":"h","showlegend":true,"x":[28.801,30.331999999999997,31.997,34.02,36.088,38.438,39.854,40.821999999999996,41.674,41.76300000000001,42.129,43.828,50.93899999999999,53.832,56.923,59.923,63.3,65.593,69.05199999999999,70.75,72.601,73.925,74.795,75.635,37.484,39.348,4
# ...

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 4
#
# **Bar Plot**
#
# **2 Points**

# %% [markdown]
# ![](images/p4.png)

# %%
### GRADED
sns.barplot(data=gapminder, x=gapminder.gdpPercap, y=gapminder.continent, orient="h")
# Out:
# <Axes: xlabel='gdpPercap', ylabel='continent'>

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 5
#
# **Scatterplot**
#
# **2 Points**

# %% [markdown]
# ![](images/p5.png)

# %%
### GRADED
fig = px.scatter(gapminder, x="gdpPercap", y="lifeExp")
fig.show()

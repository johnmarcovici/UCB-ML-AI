# %%
import pandas as pd
import requests
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
# ! pip3 install lxml html5lib

# %% [markdown]
# Get list of S&P 500 symbols

# %%
def scrape_yahoo_finance(stock: str) -> pd.DataFrame:
    url = f"https://finance.yahoo.com/quote/{stock}/history/?period1=1712523837&period2=1720386234"
    request = requests.get(
        url,
        headers={
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        },
    )
    df = pd.read_html(request.text)[0]
    df.rename(columns={"Close Close price adjusted for splits.": "Close"}, inplace=True)
    return df[["Date", "Open", "High", "Low", "Close", "Volume"]]

# %%
df = scrape_yahoo_finance("TSLA")
df
# Out:
#             Date    Open    High     Low   Close     Volume
# 0    Jul 5, 2024  249.81  252.37  242.46  251.52  154170000
# 1    Jul 3, 2024  234.56  248.35  234.25  246.39  166561500
# 2    Jul 2, 2024  218.89  231.30  218.06  231.26  205047900
# 3    Jul 1, 2024  201.02  213.23  200.85  209.86  135691400
# 4   Jun 28, 2024  199.55  203.20  195.26  197.88   95438100
# ..           ...     ...     ...     ...     ...        ...
# 57  Apr 12, 2024  172.34  173.81  170.36  171.05   64506600
# 58  Apr 11, 2024  172.55  175.88  168.51  174.60   94516000
# 59  Apr 10, 2024  173.04  174.93  170.01  171.76   84532400
# 60   Apr 9, 2024  172.91  179.22  171.92  176.88  103232700
# 61   Apr 8, 2024  169.34  174.50  167.79  172.98  104423300
#
# [62 rows x 6 columns]

# %%
def format_table(df_in: pd.DataFrame, stock: str = "") -> pd.DataFrame:
    df = df_in[["Date", "Close"]]
    df["Date"] = pd.to_datetime(df["Date"])
    df.set_index("Date", inplace=True)
    df.rename(columns={"Close": stock}, inplace=True)
    if df[stock].dtype == "O":
        # Remove rows where the closing price is contains a space - these
        # are dividend adjustment lines, then convert to float
        df = df[stock][~df[stock].str.contains(" ")].apply(float).to_frame()
    return df

# %%
df = format_table(df, stock="TSLA")
df
# Out:
#               TSLA
# Date
# 2024-07-05  251.52
# 2024-07-03  246.39
# 2024-07-02  231.26
# 2024-07-01  209.86
# 2024-06-28  197.88
# ...            ...
# 2024-04-12  171.05
# 2024-04-11  174.60
# 2024-04-10  171.76
# 2024-04-09  176.88
# 2024-04-08  172.98
#
# [62 rows x 1 columns]

# %%
some_symbols = pd.read_csv("../data/sp_500_companies.csv")["Symbol"].sample(
    50, random_state=42
)
some_symbols
# Out:
# 268     JNJ
# 73      BMY
# 289    LDOS
# 155     DOV
# 104     CVX
# 280     KKR
# 392     DGX
# 124     STZ
# 68       BX
# 244    HBAN
# 9         A
# 195     FDX
# 304     MMC
# 84      CPB
# 373      PM
# 390     PWR
# 498     XYL
# 30      AWK
# 317     MGM
# 407     RCL
# 493      WY
# 494     WMB
# 225     HAL
# 227     HAS
# 76      BRO
# 464     UNH
# 473    VTRS
# 402    RVTY
# 101     CRL
# 335    NTAP
# 296     LOW
# 222      GL
# 474    VICI
# 173     EOG
# 2       ABT
# 334    NDAQ
# 272       K
# 70     BKNG
# 210      IT
# 63      BBY
# 347    NCLH
# 93     CBRE
# 488     WFC
# 185     EXC
# 33     AMGN
# 77     BF.B
# 0       MMM
# 11     ABNB
# 310     MCD
# 22     AMZN
# Name: Symbol, dtype: object

# %%
for stock in some_symbols:
    print(f"Processing stock {stock}")
    try:
        df_stock = format_table(scrape_yahoo_finance(stock=stock), stock=stock)
    except Exception as e:
        print(f"Error retrieving data for {stock} - error was {str(e)}")
        continue
    df[stock] = df_stock[stock]
# Out:
# Processing stock JNJ
# Processing stock BMY
# Processing stock LDOS
# Processing stock DOV
# Processing stock CVX
# Processing stock KKR
# Processing stock DGX
# Processing stock STZ
# Processing stock BX
# Processing stock HBAN
# Processing stock A
# Processing stock FDX
# Processing stock MMC
# Processing stock CPB
# Processing stock PM
# Processing stock PWR
# Processing stock XYL
# Processing stock AWK
# Processing stock MGM
# Processing stock RCL
# Processing stock WY
# Processing stock WMB
# Processing stock HAL
# Processing stock HAS
# Processing stock BRO
# Processing stock UNH
# Processing stock VTRS
# Processing stock RVTY
# Processing stock CRL
# Processing stock NTAP
# Processing stock LOW
# Processing stock GL
# Processing stock VICI
# Processing stock EOG
# Processing stock ABT
# Processing stock NDAQ
# Processing stock K
# Processing stock BKNG
# Processing stock IT
# Processing stock BBY
# Processing stock NCLH
# Processing stock CBRE
# Processing stock WFC
# Processing stock EXC
# Processing stock AMGN
# Processing stock BF.B
# Error retrieving data for BF.B - error was "['Open', 'High', 'Low', 'Close', 'Volume'] not in index"
# Processing stock MMM
# Processing stock ABNB
# Processing stock MCD
# Processing stock AMZN

# %%
df
# Out:
#               TSLA     JNJ    BMY    LDOS     DOV     CVX     KKR     DGX  \
# Date
# 2024-07-05  251.52  146.48  39.66  145.51  176.68  154.31  106.08  140.45
# 2024-07-03  246.39  145.69  40.06  146.64  176.97  156.71  106.06  140.90
# 2024-07-02  231.26  146.03  40.45  145.86  176.96  156.75  105.93  136.64
# 2024-07-01  209.86  146.44  41.30  145.56  176.99  156.52  104.51  137.09
# 2024-06-28  197.88  146.16  41.53  145.88  180.45  156.42  105.24  136.88
# ...            ...     ...    ...     ...     ...     ...     ...     ...
# 2024-04-12  171.05  147.52  48.28  125.73  172.06  158.96   97.29  128.53
# 2024-04-11  174.60  148.79  49.12  126.64  173.28  161.89  100.45  130.02
# 2024-04-10  171.76  150.20  50.29  126.22  173.83  162.67   99.01  131.62
# 2024-04-09  176.88  152.29  51.60  127.10  177.35  162.00  100.27  132.75
# 2024-04-08  172.98  151.59  51.10  129.24  176.08  161.27  101.65  130.04
#
#                STZ      BX  ...    BBY   NCLH   CBRE    WFC    EXC    AMGN  \
# Date                        ...
# 2024-07-05  259.14  122.72  ...  82.45  17.48  87.21  59.62  34.31  310.88
# 2024-07-03  250.37  123.40  ...  82.33  17.54  87.39  60.66  34.73  309.38
# 2024-07-02  258.94  123.21  ...  82.17  17.61  87.08  60.97  34.53  310.77
# 2024-07-01  256.29  122.23  ...  82.29  17.68  85.97  60.59  34.55  311.01
# 2024-06-28  257.28  123.80  ...  84.29  18.79  89.11  59.39  34.61  312.45
# ...            ...     ...  ...    ...    ...    ...    ...    ...     ...
# 2024-04-12  262.24  123.47  ...  78.00  17.77  89.39  56.47  36.48  267.28
# 2024-04-11  268.34  126.87  ...  80.01  18.63  90.68  56.69  36.80  270.00
# 2024-04-10  264.92  126.08  ...  79.89  18.40  91.33  56.94  36.91  266.45
# 2024-04-09  262.97  132.00  ...  82.55  19.41  96.20  57.58  37.87  270.36
# 2024-04-08  266.00  129.32  ...  80.14  19.39  96.51  57.79  37.78  269.20
#
#                MMM    ABNB     MCD    AMZN
# Date
# 2024-07-05  101.32  152.50  251.09  200.00
# 2024-07-03  101.62  152.73  250.00  197.59
# 2024-07-02  101.62  154.34  247.79  200.00
# 2024-07-01  100.61  151.63  249.99  197.20
# 2024-06-28  102.19  151.63  254.84  193.25
# ...            ...     ...     ...     ...
# 2024-04-12   91.31  159.37  267.39  186.13
# 2024-04-11   93.18  165.42  268.62  189.05
# 2024-04-10   92.63  160.28  268.67  185.95
# 2024-04-09   92.61  162.66  269.44  185.67
# 2024-04-08   91.93  160.27  267.56  185.19
#
# [62 rows x 50 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 62 entries, 2024-07-05 to 2024-04-08
# Data columns (total 50 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TSLA    62 non-null     float64
#  1   JNJ     62 non-null     float64
#  2   BMY     62 non-null     float64
#  3   LDOS    62 non-null     float64
#  4   DOV     62 non-null     float64
#  5   CVX     62 non-null     float64
#  6   KKR     62 non-null     float64
#  7   DGX     62 non-null     float64
#  8   STZ     62 non-null     float64
#  9   BX      62 non-null     float64
#  10  HBAN    62 non-null     float64
#  11  A       62 non-null     float64
#  12  FDX     62 non-null     float64
#  13  MMC     62 non-null     float64
#  14  CPB     62 non-null     float64
#  15  PM      62 non-null     float64
#  16  PWR     62 non-null     float64
#  17  XYL     62 non-null     float64
#  18  AWK     62 non-null     float64
#  19  MGM     62 non-null     float64
#  20  RCL     62 non-null     float64
#  21  WY      62 non-null     float64
#  22  WMB     62 non-null     float64
#  23  HAL     62 non-null     float64
#  24  HAS     62 non-null     float64
#  25  BRO     62 non-null     float64
#  26  UNH     62 non-null     float64
#  27  VTRS    62 non-null     float64
#  28  RVTY    62 non-null     float64
#  29  CRL     62 non-null     float64
#  30  NTAP    62 non-null     float64
#  31  LOW     62 non-null     float64
#  32  GL      62 non-null     float64
#  33  VICI    62 non-null     float64
#  34  EOG     62 non-null     float64
#  35  ABT     62 non-null     float64
#  36  NDAQ    62 non-null     float64
#  37  K       62 non-null     float64
#  38  BKNG    62 non-null     float64
#  39  IT      62 non-null     float64
#  40  BBY     62 non-null     float64
#  41  NCLH    62 non-null     float64
#  42  CBRE    62 non-null     float64
#  43  WFC     62 non-null     float64
#  44  EXC     62 non-null     float64
#  45  AMGN    62 non-null     float64
#  46  MMM     62 non-null     float64
#  47  ABNB    62 non-null     float64
#  48  MCD     62 non-null     float64
#  49  AMZN    62 non-null     float64
# dtypes: float64(50)
# memory usage: 24.7 KB

# %%
filename = f"../data/{len(some_symbols)}_stocks.csv"
df.to_csv(filename)

# %%
dd = pd.read_csv(filename)
dd["Date"] = pd.to_datetime(dd["Date"])
dd.set_index("Date", inplace=True)
dd.equals(df)
# Out:
# True

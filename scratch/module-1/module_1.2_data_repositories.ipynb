# %%
import pandas as pd
from IPython.display import display

# %%
files = []

# Jobs in Data Science
# https://www.kaggle.com/datasets/hummaamqaasim/jobs-in-data
file = "./data/jobs_in_data.csv"
files.append(file)

# Titanic
# https://www.kaggle.com/datasets/yasserh/titanic-dataset
file = "./data/Titanic-Dataset.csv"
#files.append(file)

# Coffee Quality
# https://www.kaggle.com/datasets/fatihb/coffee-quality-data-cqi
file = "./data/df_arabica_clean.csv"
files.append(file)

# Auto Sales Data
# https://www.kaggle.com/datasets/ddosad/auto-sales-data
file = "./data/Auto Sales data.csv"
#files.append(file)

# Bank Customer Churn
file = "./data/Bank Customer Churn Prediction.csv"
files.append(file)

for file in files:
    print("----------------------------------------------------")
    print("Reading file = %s\n" % file)
    df = pd.read_csv(file)

    #print("df.head =")
    #display(df.head())

    print("df.describe =")
    display(df.describe(include = 'all'))
# Out:
# ----------------------------------------------------
# Reading file = ./data/jobs_in_data.csv
#
# df.describe =
#           work_year      job_title               job_category salary_currency  \
# count   9355.000000           9355                       9355            9355
# unique          NaN            125                         10              11
# top             NaN  Data Engineer  Data Science and Research             USD
# freq            NaN           2195                       3014            8591
# mean    2022.760449            NaN                        NaN             NaN
# std        0.519470            NaN                        NaN             NaN
# min     2020.000000            NaN                        NaN             NaN
# 25%     2023.000000            NaN                        NaN             NaN
# 50%     2023.000000            NaN                        NaN             NaN
# 75%     2023.000000            NaN                        NaN             NaN
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings; warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np

# %%
gentoo = pd.read_csv("./data/penguins.csv")
gentoo = gentoo[["bill_length_mm", "bill_depth_mm", "flipper_length_mm", "body_mass_g"]]
gentoo.describe(include="all")
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
gentoo.cov()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm          29.906333      -2.462091          50.058195
# bill_depth_mm           -2.462091       3.877888         -15.947248
# flipper_length_mm       50.058195     -15.947248         196.441677
# body_mass_g           2595.623304    -748.456122        9852.191649
#
#                      body_mass_g
# bill_length_mm       2595.623304
# bill_depth_mm        -748.456122
# flipper_length_mm    9852.191649
# body_mass_g        648372.487699

# %%
gentoo.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
#
#                    body_mass_g
# bill_length_mm        0.589451
# bill_depth_mm        -0.472016
# flipper_length_mm     0.872979
# body_mass_g           1.000000

# %%
sns.pairplot(gentoo)

# %%
gentoo.plot(kind="scatter", x="body_mass_g", y="flipper_length_mm", grid=True)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
gentoo.plot(kind="scatter", x="body_mass_g", y="bill_depth_mm", grid=True)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='bill_depth_mm'>
